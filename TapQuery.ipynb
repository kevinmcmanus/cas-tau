# %%
# !pip install astroquery
# Out:
# ...
#      |████████████████████████████████| 4.5MB 3.4MB/s
# ...
#      |████████████████████████████████| 2.7MB 39.9MB/s
# ...
#   Created wheel for astroquery: filename=astroquery-0.4-cp36-none-any.whl size=3582510 sha256=0d4afe59afb93d3cd101dd4bf97eddef5871e28d960479e13ef9bef0d5cc91dc
#   Stored in directory: /root/.cache/pip/wheels/a3/6d/9d/f6ceddc68de0e4b7a64b56d6e8c8075e6ef6377ec9c05ce128
# Successfully built astroquery
# ...

# %%
from astroquery.utils.tap.core import Tap

# %%
#from astroquery.utils.tap.core import TapPlus
tap_service_url = "http://gaia.ari.uni-heidelberg.de/tap"
#gaia = TapPlus(url="http://gea.esac.esa.int/tap-server/tap")
ari = Tap(url=tap_service_url)
#ari = TapPlus(url="http://gaia.ari.uni-heidelberg.de/tap")
tables = ari.load_tables() #only_names=True)
# Out:
# INFO: Retrieving tables... [astroquery.utils.tap.core]
# INFO: Parsing tables... [astroquery.utils.tap.core]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-9901027adfe0> in <module>()
#       3 ari = Tap(url=tap_service_url)
#       4 #ari = TapPlus(url="http://gaia.ari.uni-heidelberg.de/tap")
# ----> 5 tables = ari.load_tables() #only_names=True)
#
# /usr/local/lib/python3.6/dist-packages/astroquery/utils/tap/core.py in load_tables(self, verbose)
#     157         A list of table objects
#     158         """
# --> 159         return self.__load_tables(verbose=verbose)
#     160
#     161     def load_table(self, table, verbose=False):
#
# /usr/local/lib/python3.6/dist-packages/astroquery/utils/tap/core.py in __load_tables(self, only_names, include_shared_tables, verbose)
#     235         log.info("Parsing tables...")
# ...

# %%
>>> table = ari.load_table('gaiadr1.gaia_source')
print(table)
# Out:
# Retrieving table 'gaiadr1.gaia_source'
# Parsing table 'gaiadr1.gaia_source'...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-18706dc2be56> in <module>()
# ----> 1 table = ari.load_table('gaiadr1.gaia_source')
#       2 print(table)
#
# /usr/local/lib/python3.6/dist-packages/astroquery/utils/tap/core.py in load_table(self, table, verbose)
#     185         print("Parsing table '{}'...".format(table))
#     186         tsp = TableSaxParser()
# --> 187         tsp.parseData(response)
#     188         print("Done.")
#     189         return tsp.get_table()
#
# /usr/local/lib/python3.6/dist-packages/astroquery/utils/tap/xmlparser/tableSaxParser.py in parseData(self, data)
#      65         del self.__tables[:]
#      66         self.__status = READING_SCHEMA
# ---> 67         xml.sax.parse(data, self)
#      68         return self.__tables
#      69
#
# ...

# %%
from astroquery.gaia import Gaia, GaiaClass
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
GaiaClass.MAIN_GAIA_TABLE
# Out:
# 'gaiadr2.gaia_source'

# %%
GaiaClass

# %%
>>> from astroquery.utils.tap.core import TapPlus
>>>
>>> gaia = TapPlus(url="http://gea.esac.esa.int/tap-server/tap")
>>> tables = gaia.load_tables(only_names=True)
>>> for table in (tables):
>>>   print(table.get_qualified_name())
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443
# INFO: Retrieving tables... [astroquery.utils.tap.core]
# 404 Error 404:
# <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>404 Not Found</title>
# </head><body>
# <h1>Not Found</h1>
# <p>The requested URL /tap-server/tap/tables was not found on this server.</p>
# </body></html>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-e66082725056> in <module>()
#       2
#       3 gaia = TapPlus(url="http://geadata.esac.esa.int/tap-server/tap")
# ----> 4 tables = gaia.load_tables(only_names=True)
#       5 for table in (tables):
#       6   print(table.get_qualified_name())
#
# /usr/local/lib/python3.6/dist-packages/astroquery/utils/tap/core.py in load_tables(self, only_names, include_shared_tables, verbose)
# ...

# %%
# !pip install pyvo
# Out:
# ...
#      |████████████████████████████████| 778kB 3.4MB/s
# ...
#   Created wheel for pyvo: filename=pyvo-1.0-cp36-none-any.whl size=766553 sha256=249329d8a277ee4b71528e77bc3e7ba839e29b5275902123f5fa7d3d31e16375
#   Stored in directory: /root/.cache/pip/wheels/14/3c/25/f557df2124da27dcbf41373f0ac8606552c2b91f04edf23660
# ...
#   Created wheel for mimeparse: filename=mimeparse-0.1.3-cp36-none-any.whl size=3865 sha256=9072e78d1ba1648e67391abbba423839cebaff46a316169f24edb0b38dd34d02
#   Stored in directory: /root/.cache/pip/wheels/54/ca/c7/3db47cc5c748286db22a7fab43ccf985903d2b9ca119de16ab
# Successfully built pyvo mimeparse
# ...

# %%
#1. Import the relevant modules/classes/packages
from pyvo.dal import TAPService

#2. Query the ARI Gaia TAP Service
tap_service_url = "http://gaia.ari.uni-heidelberg.de/tap"
tap_service = TAPService(tap_service_url)
tap_results = tap_service.search("SELECT source_id, l, b, pmra, pmdec, parallax, phot_g_mean_mag as mag FROM gaiadr1.tgas_source WHERE CONTAINS(POINT('', l, b), CIRCLE('', 0, 0, 5/60.)) = 1");

#3. Print the results
print (tap_results)
# Out:
# <Table length=2>
#      source_id               l          ...        mag
#                             deg         ...        mag
#        int64              float64       ...      float64
# ------------------- ------------------- ... ------------------
# 4057483195401868032   359.9743279487605 ... 10.360127206989125
# 4057488177563931648 0.01628049349487148 ... 11.404991442492882

# %%
tap_results = tap_service.search('select top 10 source_id, r_est from gaiadr2_complements.geometric_distance')

# %%
tap_results.to_pandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7a4bfdcfc748> in <module>()
# ----> 1 tap_results.to_pandas()
#
# AttributeError: 'TAPResults' object has no attribute 'to_pandas'

# %%
tap_results = tap_service.search('select top 10 source_id, random_index from gaiadr2.gaia_source where mod(random_index,10)=3')

# %%
tap_results
# Out:
# <Table length=10>
#      source_id      random_index
#        int64           int64
# ------------------- ------------
# 5256117617491547776    369790453
# 5256117686214956032     30642983
# 5256117724882485632   1683655113
# 5256117759249387904   1657844353
# 5256118137199362304   1359031633
# 5256117724881195008   1358555063
# 5256117724881174144    223435063
# 5256118102846857856    795756583
# 5256117656163021568    303465533
# 5256212248518134144   1402335693

# %%
tap_results.to_table().to_pandas()
# Out:
#              source_id  random_index
# 0  5256117617491547776     369790453
# 1  5256117686214956032      30642983
# 2  5256117724882485632    1683655113
# 3  5256117759249387904    1657844353
# 4  5256118137199362304    1359031633
# 5  5256117724881195008    1358555063
# 6  5256117724881174144     223435063
# 7  5256118102846857856     795756583
# 8  5256117656163021568     303465533
# 9  5256212248518134144    1402335693
